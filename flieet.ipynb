# %%
import pandas as pd
import matplotlib as mt 
import numpy as np

# %%
data_inside = pd.read_csv('flew.csv')

# %%
data_inside
# Out:
#      Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                      A. Morin                       Agua Grande  1876
# 1                      A. Morin                             Kpime  1676
# 2                      A. Morin                            Atsane  1676
# 3                      A. Morin                             Akata  1680
# 4                      A. Morin                            Quilla  1704
# ...                         ...                               ...   ...
# 1790                     Zotter                              Peru   647
# 1791                     Zotter                             Congo   749
# 1792                     Zotter                      Kerala State   749
# 1793                     Zotter                      Kerala State   781
# 1794                     Zotter                Brazil, Mitzi Blue   486
#
#       Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# ...

# %%
print(data_inside)
# Out:
#      Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                      A. Morin                       Agua Grande  1876
# 1                      A. Morin                             Kpime  1676
# 2                      A. Morin                            Atsane  1676
# 3                      A. Morin                             Akata  1680
# 4                      A. Morin                            Quilla  1704
# ...                         ...                               ...   ...
# 1790                     Zotter                              Peru   647
# 1791                     Zotter                             Congo   749
# 1792                     Zotter                      Kerala State   749
# 1793                     Zotter                      Kerala State   781
# 1794                     Zotter                Brazil, Mitzi Blue   486
#
#       Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# ...

# %%
data_frame = pd.DataFrame(data_inside)

# %%
company_names = data_frame.iloc[:,0]

# %%
baenos = data_frame.iloc[:,1]

# %%
baenos
# Out:
# 0              Agua Grande
# 1                    Kpime
# 2                   Atsane
# 3                    Akata
# 4                   Quilla
#                ...
# 1790                  Peru
# 1791                 Congo
# 1792          Kerala State
# 1793          Kerala State
# 1794    Brazil, Mitzi Blue
# Name: Specific Bean Origin\nor Bar Name, Length: 1795, dtype: object

# %%
sort_of_baenos = list()
for sort in baenos:
    sort_of_baenos.append(sort)
print(sort_of_baenos)
# Out:
# ['Agua Grande', 'Kpime', 'Atsane', 'Akata', 'Quilla', 'Carenero', 'Cuba', 'Sur del Lago', 'Puerto Cabello', 'Pablino', 'Panama', 'Madagascar', 'Brazil', 'Equateur', 'Colombie', 'Birmanie', 'Papua New Guinea', 'Chuao', 'Piura', 'Chanchamayo Province', 'Chanchamayo Province', 'Bolivia', 'Peru', 'Chulucanas, El Platanal', 'Tumbes, Norandino', 'Vanua Levu', 'Vanua Levu, Toto-A', 'Vanua Levu', 'Vanua Levu, Ami-Ami-CA', 'Los Rios, Quevedo, Arriba', 'Los Rios, Quevedo, Arriba', 'Tabasco', 'Bali (west), Sukrama Family, Melaya area', 'Madagascar, Ambolikapiky P.', 'Monte Alegre, D. Badero', 'Trinite', 'Vietnam', 'Madagascar', 'Chuao', 'Piura, Perou', 'Winak Coop, Napo', 'La Dalia, Matagalpa', 'Tien Giang', 'Makwale Village, Kyela', 'Momotombo', 'Acopagro', 'CIAAB Coop', 'Villa Andina', 'Gruppo Salinas', 'Sur del Lago', 'Conacado', 'Bolivia', 'Bolivia', 'Peru', 'Morobe', 'Dos Rios', 'Guayas', 'Chuao', 'Montanya', 'Bali, Jembrana', 'Madagascar', 'Cuyagua', 'Ocumare', 'Ghana', 'Ecuador', 'Ecuado
# ...

# %%
print(sort_of_baenos, sep="\n", end="\n\n")
# Out:
# ['Agua Grande', 'Kpime', 'Atsane', 'Akata', 'Quilla', 'Carenero', 'Cuba', 'Sur del Lago', 'Puerto Cabello', 'Pablino', 'Panama', 'Madagascar', 'Brazil', 'Equateur', 'Colombie', 'Birmanie', 'Papua New Guinea', 'Chuao', 'Piura', 'Chanchamayo Province', 'Chanchamayo Province', 'Bolivia', 'Peru', 'Chulucanas, El Platanal', 'Tumbes, Norandino', 'Vanua Levu', 'Vanua Levu, Toto-A', 'Vanua Levu', 'Vanua Levu, Ami-Ami-CA', 'Los Rios, Quevedo, Arriba', 'Los Rios, Quevedo, Arriba', 'Tabasco', 'Bali (west), Sukrama Family, Melaya area', 'Madagascar, Ambolikapiky P.', 'Monte Alegre, D. Badero', 'Trinite', 'Vietnam', 'Madagascar', 'Chuao', 'Piura, Perou', 'Winak Coop, Napo', 'La Dalia, Matagalpa', 'Tien Giang', 'Makwale Village, Kyela', 'Momotombo', 'Acopagro', 'CIAAB Coop', 'Villa Andina', 'Gruppo Salinas', 'Sur del Lago', 'Conacado', 'Bolivia', 'Bolivia', 'Peru', 'Morobe', 'Dos Rios', 'Guayas', 'Chuao', 'Montanya', 'Bali, Jembrana', 'Madagascar', 'Cuyagua', 'Ocumare', 'Ghana', 'Ecuador', 'Ecuado
# ...

# %%
for intered in sort_of_baenos:
    print(intered)
# Out:
# Agua Grande
# Kpime
# Atsane
# Akata
# Quilla
# Carenero
# Cuba
# Sur del Lago
# Puerto Cabello
# Pablino
# Panama
# Madagascar
# Brazil
# Equateur
# Colombie
# Birmanie
# Papua New Guinea
# Chuao
# Piura
# Chanchamayo Province
# Chanchamayo Province
# Bolivia
# Peru
# Chulucanas, El Platanal
# Tumbes, Norandino
# Vanua Levu
# Vanua Levu, Toto-A
# Vanua Levu
# Vanua Levu, Ami-Ami-CA
# Los Rios, Quevedo, Arriba
# Los Rios, Quevedo, Arriba
# Tabasco
# Bali (west), Sukrama Family, Melaya area
# Madagascar, Ambolikapiky P.
# Monte Alegre, D. Badero
# Trinite
# Vietnam
# Madagascar
# Chuao
# Piura, Perou
# Winak Coop, Napo
# La Dalia, Matagalpa
# Tien Giang
# Makwale Village, Kyela
# Momotombo
# Acopagro
# CIAAB Coop
# Villa Andina
# Gruppo Salinas
# Sur del Lago
# Conacado
# Bolivia
# Bolivia
# Peru
# Morobe
# Dos Rios
# Guayas
# Chuao
# Montanya
# Bali, Jembrana
# Madagascar
# Cuyagua
# Ocumare
# Ghana
# Ecuador
# Ecuador
# Ghana
# LamasdelChanka, San Martin, Oro Verde coop
# ...

# %%
rates = data_frame.iloc[:,6]

# %%
rates
# Out:
# 0       3.75
# 1       2.75
# 2       3.00
# 3       3.50
# 4       3.50
#         ...
# 1790    3.75
# 1791    3.00
# 1792    3.50
# 1793    3.25
# 1794    3.00
# Name: Rating, Length: 1795, dtype: float64
